# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame([[1,np.nan,2],[2,3,5],[np.nan,4,6]])
print(df)
# Out:
#      0    1  2
# 0  1.0  NaN  2
# 1  2.0  3.0  5
# 2  NaN  4.0  6

# %%
print(df.isnull())
# Out:
#        0      1      2
# 0  False   True  False
# 1  False  False  False
# 2   True  False  False

# %%
print(df.dropna())
# Out:
#      0    1  2
# 1  2.0  3.0  5

# %%
print(df.dropna(axis=1))
# Out:
#    2
# 0  2
# 1  5
# 2  6

# %%
print(df.dropna(axis=1,how='all'))
# Out:
#      0    1  2
# 0  1.0  NaN  2
# 1  2.0  3.0  5
# 2  NaN  4.0  6

# %%
print(df.dropna(thresh=2))
# Out:
#      0    1  2
# 0  1.0  NaN  2
# 1  2.0  3.0  5
# 2  NaN  4.0  6

# %% [markdown]
# ###filling NA's

# %%
print(df.fillna(0))
# Out:
#      0    1  2
# 0  1.0  0.0  2
# 1  2.0  3.0  5
# 2  0.0  4.0  6

# %%
print(df.fillna(method="ffill"))
# Out:
#      0    1  2
# 0  1.0  NaN  2
# 1  2.0  3.0  5
# 2  2.0  4.0  6
# C:\Users\onvac\AppData\Local\Temp\ipykernel_15304\1103946584.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   print(df.fillna(method="ffill"))

# %%
print(df.fillna(method="ffill",axis = 1))
# Out:
#      0    1    2
# 0  1.0  1.0  2.0
# 1  2.0  3.0  5.0
# 2  NaN  4.0  6.0
# C:\Users\onvac\AppData\Local\Temp\ipykernel_15304\4050975924.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   print(df.fillna(method="ffill",axis = 1))

# %%
#propage value backwards
print(df.fillna(method="bfill"))
# Out:
#      0    1  2
# 0  1.0  3.0  2
# 1  2.0  3.0  5
# 2  NaN  4.0  6
# C:\Users\onvac\AppData\Local\Temp\ipykernel_15304\3172874877.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   print(df.fillna(method="bfill"))

# %% [markdown]
# ### Conditional data selection

# %%
filelang = "C:\\Users\\onvac\\OneDrive\\Desktop\\Python\\Training\\Udemy course\\MyTraining files\\ForAnaconda\\5_Data\\endangeredLang.csv"
df2 = pd.read_csv(filelang)

# %%
df2.head(n=6)
# Out:
#      ID Name in English                                          Countries  \
# 0  1022   South Italian                                              Italy
# 1  1023        Sicilian                                              Italy
# 2   383       Low Saxon  Germany, Denmark, Netherlands, Poland, Russian...
# 3   335      Belarusian  Belarus, Latvia, Lithuania, Poland, Russian Fe...
# 4   382         Lombard                                 Italy, Switzerland
# 5   405          Romani  Albania, Germany, Austria, Belarus, Bosnia and...
#
#                                Country codes alpha 3 Degree of endangerment  \
# 0                                                ITA             Vulnerable
# 1                                                ITA             Vulnerable
# 2                            DEU, DNK, NLD, POL, RUS             Vulnerable
# 3                       BRB, LVA, LTU, POL, RUS, UKR             Vulnerable
# ...

# %%
df2[3:10]
# Out:
#      ID              Name in English  \
# 3   335                   Belarusian
# 4   382                      Lombard
# 5   405                       Romani
# 6  2211             Yiddish (Israel)
# 7  1586                        Gondi
# 8  1020         Limburgian-Ripuarian
# 9  1943  Quechua of Southern Bolivia
#
#                                            Countries  \
# 3  Belarus, Latvia, Lithuania, Poland, Russian Fe...
# 4                                 Italy, Switzerland
# 5  Albania, Germany, Austria, Belarus, Bosnia and...
# 6                                             Israel
# 7                                              India
# 8                      Germany, Belgium, Netherlands
# 9                   Bolivia (Plurinational State of)
#
#                                Country codes alpha 3 Degree of endangerment  \
# 3                       BRB, LVA, LTU, POL, RUS, UKR             Vulnerable
# 4                                           ITA, CHE  Definitely endangered
# ...

# %%
df2[['Name in English','Countries']].tail(n=2)
# Out:
#      Name in English        Countries
# 2720       Zangskari  India, Pakistan
# 2721         Zidgali             Oman

# %%
df2[df2["Number of speakers"]<6000]
# Out:
#         ID              Name in English  \
# 675    432                     Chantyal
# 676   2341                  Mortlockese
# 677   1767              Baníwa do Içana
# 678    285  Akawaio (Guyana, Venezuela)
# 679   1039                      Akhvakh
# ...    ...                          ...
# 2534   131                       |'Auni
# 2535   136                         |Xam
# 2536  1443                      ǁKu ǁ'e
# 2537  1445                       ǁKx'au
# 2538   130                       ǁXegwi
#
#                                               Countries Country codes alpha 3  \
# 675                                               Nepal                   NPL
# 676                    Micronesia (Federated States of)                   FSM
# 677   Brazil, Colombia, Venezuela (Bolivarian Republ...         BRA, COL, VEN
# 678          Guyana, Venezuela (Bolivarian Republic of)              GUY, VEN
# 679                                  Russian Federation                   RUS
# ...

# %%
df2.drop(df2.index[:2],inplace = True)
df2
# Out:
#         ID       Name in English  \
# 4      382               Lombard
# 5      405                Romani
# 6     2211      Yiddish (Israel)
# 7     1586                 Gondi
# 8     1020  Limburgian-Ripuarian
# ...    ...                   ...
# 2717  1972              Yonaguni
# 2718  2018                Yucuna
# 2719  2015     Yurutí (Colombia)
# 2720  2716             Zangskari
# 2721  2177               Zidgali
#
#                                               Countries  \
# 4                                    Italy, Switzerland
# 5     Albania, Germany, Austria, Belarus, Bosnia and...
# 6                                                Israel
# 7                                                 India
# 8                         Germany, Belgium, Netherlands
# ...                                                 ...
# 2717                                              Japan
# 2718                                           Colombia
# ...

# %%
df2.drop(["Latitude"],axis=1,inplace=True)
df2
# Out:
#         ID       Name in English  \
# 4      382               Lombard
# 5      405                Romani
# 6     2211      Yiddish (Israel)
# 7     1586                 Gondi
# 8     1020  Limburgian-Ripuarian
# ...    ...                   ...
# 2717  1972              Yonaguni
# 2718  2018                Yucuna
# 2719  2015     Yurutí (Colombia)
# 2720  2716             Zangskari
# 2721  2177               Zidgali
#
#                                               Countries  \
# 4                                    Italy, Switzerland
# 5     Albania, Germany, Austria, Belarus, Bosnia and...
# 6                                                Israel
# 7                                                 India
# 8                         Germany, Belgium, Netherlands
# ...                                                 ...
# 2717                                              Japan
# 2718                                           Colombia
# ...
