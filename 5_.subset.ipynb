# %%
import pandas as pd
import numpy as np

# %%
filelang = "C:\\Users\\onvac\\OneDrive\\Desktop\\Python\\Training\\Udemy course\\MyTraining files\\ForAnaconda\\5_Data\\endangeredLang.csv"
data = pd.read_csv(filelang)
print(type(data))
data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#      ID Name in English                                          Countries  \
# 0  1022   South Italian                                              Italy
# 1  1023        Sicilian                                              Italy
# 2   383       Low Saxon  Germany, Denmark, Netherlands, Poland, Russian...
# 3   335      Belarusian  Belarus, Latvia, Lithuania, Poland, Russian Fe...
# 4   382         Lombard                                 Italy, Switzerland
#
#           Country codes alpha 3 Degree of endangerment  Number of speakers  \
# 0                           ITA             Vulnerable           7500000.0
# 1                           ITA             Vulnerable           5000000.0
# 2       DEU, DNK, NLD, POL, RUS             Vulnerable           4800000.0
# 3  BRB, LVA, LTU, POL, RUS, UKR             Vulnerable           4000000.0
# 4                      ITA, CHE  Definitely endangered           3500000.0
#
# ...

# %%
data[2:]
# Out:
#         ID    Name in English  \
# 2      383          Low Saxon
# 3      335         Belarusian
# 4      382            Lombard
# 5      405             Romani
# 6     2211   Yiddish (Israel)
# ...    ...                ...
# 2717  1972           Yonaguni
# 2718  2018             Yucuna
# 2719  2015  Yurutí (Colombia)
# 2720  2716          Zangskari
# 2721  2177            Zidgali
#
#                                               Countries  \
# 2     Germany, Denmark, Netherlands, Poland, Russian...
# 3     Belarus, Latvia, Lithuania, Poland, Russian Fe...
# 4                                    Italy, Switzerland
# 5     Albania, Germany, Austria, Belarus, Bosnia and...
# 6                                                Israel
# ...                                                 ...
# 2717                                              Japan
# 2718                                           Colombia
# 2719                                           Colombia
# ...

# %%
data[::3]
# Out:
#         ID                             Name in English  \
# 0     1022                               South Italian
# 3      335                                  Belarusian
# 6     2211                            Yiddish (Israel)
# 9     1943                 Quechua of Southern Bolivia
# 12     349                            Emilian-Romagnol
# ...    ...                                         ...
# 2709  2475                                          Wa
# 2712   283  Western Abenaki (United States of America)
# 2715  1365                                  Yazva Komi
# 2718  2018                                      Yucuna
# 2721  2177                                     Zidgali
#
#                                               Countries  \
# 0                                                 Italy
# 3     Belarus, Latvia, Lithuania, Poland, Russian Fe...
# 6                                                Israel
# 9                      Bolivia (Plurinational State of)
# ...

# %%
data.iloc[[3,5], 2:5]
# Out:
#                                            Countries  \
# 3  Belarus, Latvia, Lithuania, Poland, Russian Fe...
# 5  Albania, Germany, Austria, Belarus, Bosnia and...
#
#                                Country codes alpha 3 Degree of endangerment
# 3                       BRB, LVA, LTU, POL, RUS, UKR             Vulnerable
# 5  ALB, DEU, AUT, BRB, BIH, BGR, HRV, EST, FIN, F...  Definitely endangered

# %%
data.loc[[4:8],:]
# Out:
#   Cell In[20], line 1
#     data.loc[[4:8],:]
#                ^
# SyntaxError: invalid syntax

# %%
# CHECK data[['Countries','Name in English']][4:8]
# Out:
#                                            Countries   Name in English
# 4                                 Italy, Switzerland           Lombard
# 5  Albania, Germany, Austria, Belarus, Bosnia and...            Romani
# 6                                             Israel  Yiddish (Israel)
# 7                                              India             Gondi

# %%
data[data.Countries == "Italy"].head()
# Out:
#       ID Name in English Countries Country codes alpha 3  \
# 0   1022   South Italian     Italy                   ITA
# 1   1023        Sicilian     Italy                   ITA
# 13   399     Piedmontese     Italy                   ITA
# 36   337     Campidanese     Italy                   ITA
# 53   353        Friulian     Italy                   ITA
#
#    Degree of endangerment  Number of speakers  Latitude  Longitude  \
# 0              Vulnerable           7500000.0   40.9798    15.2490
# 1              Vulnerable           5000000.0   37.4399    14.5019
# 13  Definitely endangered           2000000.0   45.2013     7.8662
# 36  Definitely endangered            900000.0   39.2991     8.9868
# 53  Definitely endangered            600000.0   46.1037    13.1396
#
#                           Description of the location
# 0   Campania, Lucania (Basilicata), Abruzzi (Abruz...
# 1   Sicily (Sicilia), southern and central Calabri...
# ...

# %%
data[data.Countries.isin(["Italy","Germany"])].tail()
# Out:
#         ID Name in English Countries Country codes alpha 3  \
# 1315   351          Faetar     Italy                   ITA
# 1455  1345        Cimbrian     Italy                   ITA
# 1506   357         Gardiol     Italy                   ITA
# 1663  1344        Töitschu     Italy                   ITA
# 2470   403        Polabian   Germany                   DEU
#
#       Degree of endangerment  Number of speakers  Latitude  Longitude  \
# 1315  Degree_of_endangerment               600.0   41.3265    15.1721
# 1455  Degree_of_endangerment               400.0   45.8670    11.4268
# 1506  Degree_of_endangerment               340.0   39.4658    15.9933
# 1663  Degree_of_endangerment               200.0   45.6913     7.8682
# 2470  Degree_of_endangerment                 0.0   53.0940    11.3461
#
#                             Description of the location
# 1315  Faeto and Celle San Vito in Foggia Province in...
# 1455  vigorously spoken in Luserna (Lusern) in Trent...
# ...

# %%
df = data[:]

df.rename(columns={"Degree of endangerment": "Degree_of_endangerment"},inplace=True)
print(df)

df[(df.Countries == "India") & (df.Degree_of_endangerment == "Vulnerable")]
# Out:
#         ID    Name in English  \
# 0     1022      South Italian
# 1     1023           Sicilian
# 2      383          Low Saxon
# 3      335         Belarusian
# 4      382            Lombard
# ...    ...                ...
# 2717  1972           Yonaguni
# 2718  2018             Yucuna
# 2719  2015  Yurutí (Colombia)
# 2720  2716          Zangskari
# 2721  2177            Zidgali
#
#                                               Countries  \
# 0                                                 Italy
# 1                                                 Italy
# 2     Germany, Denmark, Netherlands, Poland, Russian...
# 3     Belarus, Latvia, Lithuania, Poland, Russian Fe...
# 4                                    Italy, Switzerland
# ...                                                 ...
# 2717                                              Japan
# 2718                                           Colombia
# 2719                                           Colombia
# ...

# %%
large = data.sort_values(by="Number of speakers",ascending=False)
large.head(n=8)
# Out:
#      ID   Name in English                                          Countries  \
# 0  1022     South Italian                                              Italy
# 1  1023          Sicilian                                              Italy
# 2   383         Low Saxon  Germany, Denmark, Netherlands, Poland, Russian...
# 3   335        Belarusian  Belarus, Latvia, Lithuania, Poland, Russian Fe...
# 4   382           Lombard                                 Italy, Switzerland
# 5   405            Romani  Albania, Germany, Austria, Belarus, Bosnia and...
# 6  2211  Yiddish (Israel)                                             Israel
# 7  1586             Gondi                                              India
#
#                                Country codes alpha 3  Degree of endangerment  \
# 0                                                ITA  Degree_of_endangerment
# 1                                                ITA  Degree_of_endangerment
# ...

# %%
bystatus = data.groupby("Degree of endangerment")
bystatus.head()
# Out:
#         ID         Name in English  \
# 0     1022           South Italian
# 1     1023                Sicilian
# 2      383               Low Saxon
# 3      335              Belarusian
# 4      382                 Lombard
# 5      405                  Romani
# 6     2211        Yiddish (Israel)
# 7     1586                   Gondi
# 12     349        Emilian-Romagnol
# 13     399             Piedmontese
# 48     398                  Picard
# 62     375            Languedocian
# 77    2165        Judezmo (Israel)
# 79     378                Limousin
# 104    336                  Breton
# 232   1587                   Parji
# 250   2180                Zenatiya
# 307   1490                    Mayo
# 310   1561                Sirmaudi
# 332   2181                Tidikelt
# 485   2618                 Tobada'
# 1040  2059  Tamazight (Ait Rouadi)
# 2221   580               Canichana
# 2269  2112                     Lae
# 2277   661                     Uru
#
# ...

# %%
data.groupby(["Countries","Degree of endangerment"]).count()
# Out:
#                                                                            ID  \
# Countries                                          Degree of endangerment
# Afghanistan                                        Critically endangered    2
#                                                    Definitely endangered    5
#                                                    Severely endangered      4
#                                                    Vulnerable               1
# Albania, Algeria, Bosnia and Herzegovina, Bulga... Severely endangered      1
# ...                                                                        ..
# Viet Nam                                           Severely endangered      2
#                                                    Vulnerable               4
# Western Sahara                                     Critically endangered    1
# Yemen                                              Definitely endangered    1
# ...

# %%
x = data["Number of speakers"].groupby(data['Countries'])
x.head()
# Out:
# 0       7500000.0
# 1       5000000.0
# 2       4800000.0
# 3       4000000.0
# 4       3500000.0
#           ...
# 2689          NaN
# 2705          NaN
# 2708          NaN
# 2713          NaN
# 2716          NaN
# Name: Number of speakers, Length: 662, dtype: float64

# %%
data["vfew"] = data["Number of speakers"].apply(lambda x: x <= 5000)
data.head(n=6)
# Out:
#      ID Name in English                                          Countries  \
# 0  1022   South Italian                                              Italy
# 1  1023        Sicilian                                              Italy
# 2   383       Low Saxon  Germany, Denmark, Netherlands, Poland, Russian...
# 3   335      Belarusian  Belarus, Latvia, Lithuania, Poland, Russian Fe...
# 4   382         Lombard                                 Italy, Switzerland
# 5   405          Romani  Albania, Germany, Austria, Belarus, Bosnia and...
#
#                                Country codes alpha 3 Degree of endangerment  \
# 0                                                ITA             Vulnerable
# 1                                                ITA             Vulnerable
# 2                            DEU, DNK, NLD, POL, RUS             Vulnerable
# 3                       BRB, LVA, LTU, POL, RUS, UKR             Vulnerable
# ...

# %%
group_by_5K=data.groupby(["vfew"])
group_by_5K.size()
# Out:
# vfew
# False     879
# True     1843
# dtype: int64

# %%
group_by_5KC = data.groupby(["vfew","Countries"])
group_by_5KC.size()
# Out:
# vfew   Countries
# False  Afghanistan                                                                                                                                                                                                                                                                                                                                                                                      2
#        Albania, Algeria, Bosnia and Herzegovina, Bulgaria, Croatia, Greece, The former Yugoslav Republic of Macedonia, Morocco, Romania, Turkey, Serbia                                                                                                                                                                                                                                                 1
# ...

# %% [markdown]
# ## Cross-tab

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("C:\\Users\\onvac\\OneDrive\\Desktop\\Python\\Training\\Udemy course\\MyTraining files\\ForAnaconda\\5_Data\\endangeredLang2.csv")
data.head(n=6)
# Out:
#      ID   EnglishNames                                          Countries  \
# 0  1022  South Italian                                              Italy
# 1  1023       Sicilian                                              Italy
# 2   383      Low Saxon  Germany, Denmark, Netherlands, Poland, Russian...
# 3   335     Belarusian  Belarus, Latvia, Lithuania, Poland, Russian Fe...
# 4   382        Lombard                                 Italy, Switzerland
# 5   405         Romani  Albania, Germany, Austria, Belarus, Bosnia and...
#
#                                          CountryCode           Endangerment  \
# 0                                                ITA             Vulnerable
# 1                                                ITA             Vulnerable
# 2                            DEU, DNK, NLD, POL, RUS             Vulnerable
# 3                       BRB, LVA, LTU, POL, RUS, UKR             Vulnerable
# ...

# %%
x = pd.crosstab(data["CountryCode"],data["Endangerment"],margins = True)
x.head(4)
# Out:
# Endangerment                                        Critically endangered  \
# CountryCode
# AFG                                                                     2
# ALB, BGR, GRC, MKD, SRB                                                 0
# ALB, BGR, MKD, ROU, SRB                                                 0
# ALB, DEU, AUT, BRB, BIH, BGR, HRV, EST, FIN, FR...                      0
#
# Endangerment                                        Definitely endangered  \
# CountryCode
# AFG                                                                     5
# ALB, BGR, GRC, MKD, SRB                                                 1
# ALB, BGR, MKD, ROU, SRB                                                 0
# ALB, DEU, AUT, BRB, BIH, BGR, HRV, EST, FIN, FR...                      1
#
# Endangerment                                        Extinct  \
# CountryCode
# AFG                                                       0
# ...

# %%
def perConvert(var):
    return var/float(var[-1])

# %%
x = pd.crosstab(data["CountryCode"],data["Endangerment"],margins=True).apply(perConvert,axis=1)
x.head(3)
# Out:
# C:\Users\onvac\AppData\Local\Temp\ipykernel_11160\3694094084.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return var/float(var[-1])
# Endangerment             Critically endangered  Definitely endangered  \
# CountryCode
# AFG                                   0.166667               0.416667
# ALB, BGR, GRC, MKD, SRB               0.000000               1.000000
# ALB, BGR, MKD, ROU, SRB               0.000000               0.000000
#
# Endangerment             Extinct  Severely endangered  Vulnerable  All
# CountryCode
# AFG                          0.0             0.333333    0.083333  1.0
# ALB, BGR, GRC, MKD, SRB      0.0             0.000000    0.000000  1.0
# ALB, BGR, MKD, ROU, SRB      0.0             0.000000    1.000000  1.0

# %% [markdown]
# ### *Reshaping*

# %%
import pandas as pd
import numpy as np

# %%
# Out:
#      ID   EnglishNames                                          Countries  \
# 0  1022  South Italian                                              Italy
# 1  1023       Sicilian                                              Italy
# 2   383      Low Saxon  Germany, Denmark, Netherlands, Poland, Russian...
# 3   335     Belarusian  Belarus, Latvia, Lithuania, Poland, Russian Fe...
# 4   382        Lombard                                 Italy, Switzerland
# 5   405         Romani  Albania, Germany, Austria, Belarus, Bosnia and...
#
#                                          CountryCode           Endangerment  \
# 0                                                ITA             Vulnerable
# 1                                                ITA             Vulnerable
# 2                            DEU, DNK, NLD, POL, RUS             Vulnerable
# 3                       BRB, LVA, LTU, POL, RUS, UKR             Vulnerable
# ...

# %%
dstack = data.stack()
dstack
# Out:
# 0     ID                               1022
#       EnglishNames            South Italian
#       Countries                       Italy
#       CountryCode                       ITA
#       Endangerment               Vulnerable
#                               ...
# 2721  Countries                        Oman
#       CountryCode                       OMN
#       Endangerment    Critically endangered
#       Latitude                      23.4027
#       Longitude                     58.0957
# Length: 21585, dtype: object

# %%
d = dstack.unstack()
d
# Out:
#         ID       EnglishNames  \
# 0     1022      South Italian
# 1     1023           Sicilian
# 2      383          Low Saxon
# 3      335         Belarusian
# 4      382            Lombard
# ...    ...                ...
# 2717  1972           Yonaguni
# 2718  2018             Yucuna
# 2719  2015  Yurutí (Colombia)
# 2720  2716          Zangskari
# 2721  2177            Zidgali
#
#                                               Countries  \
# 0                                                 Italy
# 1                                                 Italy
# 2     Germany, Denmark, Netherlands, Poland, Russian...
# 3     Belarus, Latvia, Lithuania, Poland, Russian Fe...
# 4                                    Italy, Switzerland
# ...                                                 ...
# 2717                                              Japan
# 2718                                           Colombia
# 2719                                           Colombia
# ...

# %%
patient=pd.DataFrame({"FirstName" : ["Bill","Jane"],
                      "LastName" : ["Shakespeare","Austen"],
                      "Bloodtype" : ["0+","B+"],
                      "Wt" : [85,62]})
print(patient)
print(pd.melt(patient, id_vars = ["FirstName","LastName"], var_name = "measurements"))
# Out:
#   FirstName     LastName Bloodtype  Wt
# 0      Bill  Shakespeare        0+  85
# 1      Jane       Austen        B+  62
#   FirstName     LastName measurements value
# 0      Bill  Shakespeare    Bloodtype    0+
# 1      Jane       Austen    Bloodtype    B+
# 2      Bill  Shakespeare           Wt    85
# 3      Jane       Austen           Wt    62

# %%
x=data[0:15]
x.drop(["ID","EnglishNames","CountryCode","Latitude","Longitude"], axis = 1, inplace = True)
print(x.head())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[49], line 2
#       1 x=data[0:15]
# ----> 2 x.drop(["ID","EnglishNames","CountryCode","Latitude","Longitude"], axis = 1, inplace = True)
#       3 print(x.head())
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
# ...

# %% [markdown]
# ### **Pivoting**

# %%
data2 = pd.read_csv("C:\\Users\\onvac\\OneDrive\\Desktop\\Python\\Training\\Udemy course\\MyTraining files\\ForAnaconda\\5_Data\\GlobalFirePower.csv")
data2.head(6)
# Out:
#           Country ISO3  Rank  Total Population  Manpower Available  \
# 0   United States  USA     1         323995528           145215000
# 1          Russia  RUS     2         142355415            70000000
# 2           China  CHN     3        1373541278           750000000
# 3           India  IND     4        1266883598           616000000
# 4          France  FRA     5          66836154            30000000
# 5  United Kingdom  UKD     6          64430428            30000000
#
#    Fit-for-Service  Reaching Military Age  Total Military Personnel  \
# 0        120025000                4220000                   2363675
# 1         47000000                1355000                   3371027
# 2        619000000               19550000                   3712500
# 3        489600000               22900000                   4207250
# 4         23750000                 775000                    387635
# 5         24040000                 750000                    232675
#
# ...

# %%
x = pd.pivot_table(data2,index=["ISO3"])
#x(6)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1942, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1941 try:
# -> 1942     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943 except Exception as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:885, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     884 for i, group in enumerate(splitter):
# --> 885     res = func(group)
#     886     res = extract_result(res)
#
# ...

# %%
data = pd.read_csv("C:\\Users\\onvac\\OneDrive\\Desktop\\Python\\Training\\Udemy course\\MyTraining files\\ForAnaconda\\5_Data\\endangeredLang2.csv")
data.head(n=6)
# Out:
#      ID   EnglishNames                                          Countries  \
# 0  1022  South Italian                                              Italy
# 1  1023       Sicilian                                              Italy
# 2   383      Low Saxon  Germany, Denmark, Netherlands, Poland, Russian...
# 3   335     Belarusian  Belarus, Latvia, Lithuania, Poland, Russian Fe...
# 4   382        Lombard                                 Italy, Switzerland
# 5   405         Romani  Albania, Germany, Austria, Belarus, Bosnia and...
#
#                                          CountryCode           Endangerment  \
# 0                                                ITA             Vulnerable
# 1                                                ITA             Vulnerable
# 2                            DEU, DNK, NLD, POL, RUS             Vulnerable
# 3                       BRB, LVA, LTU, POL, RUS, UKR             Vulnerable
# ...

# %%
p = pd.pivot_table(data,index=["CountryCode","Endangerment"],values = ["No"], aggfunc=np.sum)
p
# Out:
# C:\Users\onvac\AppData\Local\Temp\ipykernel_4364\3445579712.py:1: FutureWarning: The provided callable <function sum at 0x0000019BFA1F22A0> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   p = pd.pivot_table(data,index=["CountryCode","Endangerment"],values = ["No"], aggfunc=np.sum)
#                                                      No
# CountryCode             Endangerment
# AFG                     Critically endangered     300.0
#                         Definitely endangered   14000.0
#                         Severely endangered      4200.0
#                         Vulnerable                  0.0
# ALB, BGR, GRC, MKD, SRB Definitely endangered  500000.0
# ...                                                 ...
# ZAF                     Extinct                     0.0
# ZAI                     Critically endangered      10.0
# ...

# %% [markdown]
# ### ***rank and sort***

# %%
s=pd.Series(range(4),index=['d','a','b','c'])
print(type(s))
print(s)
# Out:
# <class 'pandas.core.series.Series'>
# d    0
# a    1
# b    2
# c    3
# dtype: int64

# %%
s2= s.sort_index()
s2
# Out:
# a    1
# b    2
# c    3
# d    0
# dtype: int64

# %%
s3 = s.sort_index(axis=1,ascending = False)
s3
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(cls, axis)
#     576             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     577         except KeyError:
# --> 578             raise ValueError(f"No axis named {axis} for object type {cls.__name__}")
#
# KeyError: 1
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4364\3729081930.py in ?()
# ----> 1 s3 = s.sort_index(axis=1,ascending = False)
#       2 s3
#
# ~\anaconda3\Lib\site-packages\pandas\core\series.py in ?(self, axis, level, ascending, inplace, kind, na_position, sort_remaining, ignore_index, key)
#    4065         d    4
#    4066         dtype: int64
#    4067         """
#    4068
# -> 4069         return super().sort_index(
# ...

# %%
x = s.sort_values(by = ['ISO3'])
x
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[86], line 1
# ----> 1 x = s.sort_values(by = ['ISO3'])
#       2 x
#
# TypeError: Series.sort_values() got an unexpected keyword argument 'by'
